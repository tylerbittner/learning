# %% [markdown]
# # Elements of Data Science Part 5: Model Evaluation & Productionization
# [Course link](https://www.aws.training/Details/eLearning?id=26598)

# %% [markdown]
# ## Normal (Gaussian) Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from statistics import mean

domain = np.linspace(-3, 3, 1000)           # np.linspace(start, stop, num_samples)
plt.plot(domain, norm.pdf(domain, 0, 1))    # norm.pdf(X, mean, std_dev)
plt.title("Normal distribution")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.show()

# %%
print(f"mean/mu = {round(mean(domain))}")
# Out:
# mean/mu = -0.0
